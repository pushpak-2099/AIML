# %% [markdown]
# STEMING

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# Porter stemmer

# %%
from nltk.stem import PorterStemmer

steming=PorterStemmer()

for word in words:
    print(word,"----->",steming.stem(word) )
# Out:
# eating -----> eat
# eats -----> eat
# eaten -----> eaten
# writing -----> write
# writes -----> write
# programming -----> program
# programs -----> program
# history -----> histori
# finally -----> final
# finalized -----> final

# %% [markdown]
# rege stemer

# %%
from nltk.stem import RegexpStemmer

rege_stem=RegexpStemmer('ing$|s$|e$|able$', min=4)


rege_stem.stem('eating')
# Out:
# 'eat'

# %% [markdown]
# SNOWBALL STEMMER

# %%
from nltk.stem import SnowballStemmer  ## it is same as poter stemmer but better

snowball=SnowballStemmer("english")

for word in words:
    print(word ,"------->" ,snowball.stem(word))
# Out:
# eating -------> eat
# eats -------> eat
# eaten -------> eaten
# writing -------> write
# writes -------> write
# programming -------> program
# programs -------> program
# history -------> histori
# finally -------> final
# finalized -------> final
