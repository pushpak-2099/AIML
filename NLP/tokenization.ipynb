# %%
corpus=""" This is my nlp leanings. Starting with tokenization.
Trying to do better!"""

# %%
corpus
# Out:
# ' This is my nlp leanings. Starting with tokenization.\nTrying to do better!'

# %%
print(corpus)
# Out:
#  This is my nlp leanings. Starting with tokenization.
# Trying to do better!

# %%
# paragraph ----> sentences
# it converts the paragraphs into sentences and give it as a list of sentences
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
text="hello ,this is my first time doing this."

# %%
words = word_tokenize(text)
words
# Out:
# ['hello', ',', 'this', 'is', 'my', 'first', 'time', 'doing', 'this', '.']

# %%
documents=sent_tokenize(corpus)

# %%
from nltk.tokenize import  word_tokenize

# %%
words=word_tokenize(corpus)

words
# Out:
# ['This',
#  'is',
#  'my',
#  'nlp',
#  'leanings',
#  '.',
#  'Starting',
#  'with',
#  'tokenization',
#  '.',
#  'Trying',
#  'to',
#  'do',
#  'better',
#  '!']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokrnizer = TreebankWordTokenizer() 

tokrnizer.tokenize(corpus)  ## it include fullstop in last word
# Out:
# ['This',
#  'is',
#  'my',
#  'nlp',
#  'leanings.',
#  'Starting',
#  'with',
#  'tokenization.',
#  'Trying',
#  'to',
#  'do',
#  'better',
#  '!']
