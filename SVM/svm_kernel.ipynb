# %%
import numpy as np 
import matplotlib.pyplot as plt

x= np.linspace(-0.5,0.5,100)
y=np.sqrt(10**2-x**2)
y=np.hstack([y,-y])
x=np.hstack([x,-x])

# %%
x1= np.linspace(-0.5,0.5,100)
y1=np.sqrt(5**2-x**2)
y1=np.hstack([y,-y])
x1=np.hstack([x,-x])
